# %%
#read
f = open("data.txt","r")
print(f.read())
f.close()
# Out:
# I am Soumiya
# Pursuing B.Tech IT in SSN

# %%
#write
f = open("data.txt", "w")
f.write("I completed my high school in Mount Zion")
f.close()

f = open("data.txt","r")
print(f.read())
# Out:
# I completed my high school in Mount Zion

# %%
#append
f = open("data.txt","a")
f.write("\nMy native place is Pudukkottai")
f.close()

f = open("data.txt","r")
print(f.read())
# Out:
# I completed my high school in Mount Zion
# My native place is Pudukkottai
#
# My native place is Pudukkottai

# %%
#new file
f = open("soumiverse.txt","x")
f.write("Welcome to my Channel")
f.close()

f = open("soumiverse.txt","r")
print(f.read())
# Out:
# Welcome to my Channel

# %%
emp[]
def emp_details(id,hw,t,c,s,cat):
    return(id,hw,t,c,s,cat)
n= int(input("Enter the no"))
for i in range(n+1):
    id = int(input())
    hw = int(input())
    t = int(input())
    c = int(input())
    s = int(input())
    cat = int(input())
    yee = emp_details(id,hw,t,c,s,cat)
    emp.append(yee)

# %%
#Student scholarship
scholar = []
def stu_sch(id,name,num,total):
    return[id,name,num,total]
n = int(input("Enter the number of :"))
for i in range(n):
    id = input("id: ")
    name = input("name: ")
    num = input("No. : ")
    total = int(input("Total mark: "))
    s =[id,name,num,total]
    scholar.append(s)
print("Added successfully")

def compute():
    for i in scholar:
        mark_percent = i[3]
        if mark_percent >= 95:
            amount = 50000
        elif 90<= mark_percent <95:
            amount = 20000
        elif 85<= mark_percent <90:
            amount = 10000
        else:
            print("You are not eligible")
        i.append(amount)
    print(i)
compute()

def display():
    high = []
    for i in scholar:
        if i[4] == 50000:
            high.append(i)
    print(high)
display()

def update_scholar(tup):
    with open("scholar.txt","w") as file:
        file.write(f"{tup[1]},{tup[4]}\n")
    with open("scholar.txt","r") as file:
        print(file.read)
# Out:
# Added successfully
# ['123', 'sd', '3', 99, 50000]
# [['123', 'sd', '3', 99, 50000]]

# %%
# Ensure a file named 'example.txt' exists in the same directory
with open('example.txt', 'r') as f:
    for line in f:
        print(line.rstrip())
